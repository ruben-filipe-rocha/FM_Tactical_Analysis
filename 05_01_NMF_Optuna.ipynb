# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import (
    silhouette_score,
    davies_bouldin_score,
    calinski_harabasz_score,
    pairwise_distances_argmin_min
)

from tqdm.notebook import tqdm
from scipy.ndimage import gaussian_filter1d

# %%
# ==== 0) Parâmetros ====
ARQ_IN    = "Matrix.csv"        # saída do passo anterior (pivot pronto)
OUT_W     = "W_frames.csv"      # pesos por frame (frames × K)
OUT_H     = "H_padroes.csv"     # padrões (K × células)
OUT_TOP   = "frames_tipicos.csv"
SEED      = 42
MAX_ITER  = 2000

# ==== 1) Ler matriz ====
X = pd.read_csv(ARQ_IN, index_col=0)
X = X.clip(lower=0).astype(float)

# %%
print(f"Dimensões da matriz X: {X.shape}")  # (n_frames, n_cells)
# Out:
# Dimensões da matriz X: (1016, 1075)

# %%
# ==== 4) Optimização com Optuna (multi-objetivo: KL + Calinski) ====
import optuna
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import calinski_harabasz_score

def objective(trial):
    # pesquisar nº de componentes (fatores latentes)
    n_components = trial.suggest_int("n_components", 2, min(40, X.shape[1]))

    alpha_H = trial.suggest_float("alpha_H", 1e-5, 1e-2, log=True)
    alpha_W = trial.suggest_float("alpha_W", 1e-5, 1e-2, log=True)
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    nmf = NMF(
        n_components=n_components,
        init="nndsvda",
        solver="mu",
        beta_loss="kullback-leibler",
        max_iter=MAX_ITER,
        random_state=SEED,
        alpha_H=alpha_H,
        alpha_W=alpha_W,
        l1_ratio=l1_ratio
    )

    W = nmf.fit_transform(X.values)
    H = nmf.components_
    X_hat = W @ H

    # ----------------
    # 1. Divergência KL ↓
    # ----------------
    mask = X.values > 0
    kl = np.sum(
        X.values[mask] * np.log(X.values[mask] / np.maximum(X_hat[mask], 1e-10))
        - X.values[mask] + X_hat[mask]
    )

    # ----------------
    # 2. Calinski-Harabasz ↑
    # ----------------
    scaler = StandardScaler()
    W_scaled = scaler.fit_transform(W)

    kmeans = KMeans(n_clusters=n_components, random_state=SEED)
    labels = kmeans.fit_predict(W_scaled)

    try:
        calinski = calinski_harabasz_score(W_scaled, labels)
    except Exception:
        calinski = 0

    return kl, calinski


# ==== Multi-Objective Study ====
study = optuna.create_study(
    directions=["minimize", "maximize"],  # KL ↓, Calinski ↑
    sampler=optuna.samplers.NSGAIISampler(seed=SEED)
)

study.optimize(objective, n_trials=100)

# ==== Resultados ====
print("Número de soluções no Pareto front:", len(study.best_trials))
print("\n➡️ Soluções ótimas (compromissos KL vs Calinski):")
for t in study.best_trials:
    vals = t.values
    print(f"KL={vals[0]:.2f}, Calinski={vals[1]:.2f}, Params={t.params}")

# ---- Selecionar 1 solução do Pareto front ----
chosen_trial = study.best_trials[0]
best_params = chosen_trial.params
print("\n➡️ Solução mais equilibrada escolhida automaticamente:")
print(f"KL={chosen_trial.values[0]:.2f}, Calinski={chosen_trial.values[1]:.2f}")
print(f"Parâmetros: {best_params}")
# Out:
# [I 2025-10-10 17:25:22,710] A new study created in memory with name: no-name-3abcb4cc-c7a3-4de3-b091-f567ed9b79e6
# [I 2025-10-10 17:25:23,995] Trial 0 finished with values: [157641.71067088004, 136.697319114797] and parameters: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}.
# [I 2025-10-10 17:25:24,868] Trial 1 finished with values: [178964.86607051388, 357.3095678187624] and parameters: {'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}.
# [I 2025-10-10 17:25:26,181] Trial 2 finished with values: [137581.08300856443, 69.3927894927399] and parameters: {'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 1.1527987128232396e-05, 'l1_ratio': 0.9699098521619943}.
# [I 2025-10-10 17:25:27,417] Trial 3 finished with values: [124275.44069970748, 54.42699829067487] and parameters: {'n_components': 34, 'alpha_H': 4.335281794951564e-05, 'alpha_W': 3.511356313970405e-05, 'l1_ratio': 0.18340450985343382}.
# [I 2025-10-10 17:25:28,474] Trial 4 finished with values: [162861.22375129588, 173.20823676325426] and parameters: {'n_components': 13, 'alpha_H': 0.00037520558551242813, 'alpha_W': 0.00019762189340280086, 'l1_ratio': 0.2912291401980419}.
# [I 2025-10-10 17:25:29,831] Trial 5 finished with values: [137209.1750618755, 75.29434835029916] and parameters: {'n_components': 25, 'alpha_H': 2.621087878265438e-05, 'alpha_W': 7.52374288453485e-05, 'l1_ratio': 0.3663618432936917}.
# [I 2025-10-10 17:25:31,615] Trial 6 finished with values: [150237.10066252717, 84.16174581042492] and parameters: {'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:25:32,968] Trial 7 finished with values: [137190.11505355372, 76.7934262594072] and parameters: {'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}.
# [I 2025-10-10 17:25:33,611] Trial 8 finished with values: [202094.2206764429, 1114.541503192055] and parameters: {'n_components': 4, 'alpha_H': 0.007025166339242158, 'alpha_W': 0.00788671412999049, 'l1_ratio': 0.8083973481164611}.
# [I 2025-10-10 17:25:34,494] Trial 9 finished with values: [162717.9185229842, 163.83611456065353] and parameters: {'n_components': 13, 'alpha_H': 1.9634341572933338e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.4401524937396013}.
# [I 2025-10-10 17:25:35,202] Trial 10 finished with values: [187549.82049972384, 524.5592237363593] and parameters: {'n_components': 6, 'alpha_H': 0.0003058656666978527, 'alpha_W': 1.2681352169084594e-05, 'l1_ratio': 0.9093204020787821}.
# [I 2025-10-10 17:25:36,291] Trial 11 finished with values: [166684.51112587616, 141.3370564641703] and parameters: {'n_components': 12, 'alpha_H': 0.0009717775305059633, 'alpha_W': 8.612579192594876e-05, 'l1_ratio': 0.5200680211778108}.
# [I 2025-10-10 17:25:37,539] Trial 12 finished with values: [142196.49671463523, 74.78166514682121] and parameters: {'n_components': 23, 'alpha_H': 3.585612610345396e-05, 'alpha_W': 0.008105016126411584, 'l1_ratio': 0.7751328233611146}.
# [I 2025-10-10 17:25:38,945] Trial 13 finished with values: [121752.70048765538, 50.46971098013535] and parameters: {'n_components': 38, 'alpha_H': 0.004835952776465951, 'alpha_W': 0.0006218704727769079, 'l1_ratio': 0.9218742350231168}.
# [I 2025-10-10 17:25:39,471] Trial 14 finished with values: [192338.77891544302, 708.6851190825555] and parameters: {'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 1.3667272915456215e-05, 'l1_ratio': 0.32533033076326434}.
# [I 2025-10-10 17:25:40,650] Trial 15 finished with values: [153267.45513547986, 104.63711666218279] and parameters: {'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}.
# [I 2025-10-10 17:25:41,650] Trial 16 finished with values: [166646.469508328, 173.4123384517138] and parameters: {'n_components': 12, 'alpha_H': 0.00042470585622618684, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.8021969807540397}.
# [I 2025-10-10 17:25:42,238] Trial 17 finished with values: [199925.31412927108, 1124.4264154080154] and parameters: {'n_components': 4, 'alpha_H': 0.009133995846860976, 'alpha_W': 0.0020736445177905022, 'l1_ratio': 0.1987156815341724}.
# [I 2025-10-10 17:25:42,597] Trial 18 finished with values: [230050.98763891077, 3068.7936853057727] and parameters: {'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:25:44,064] Trial 19 finished with values: [126644.14688814219, 55.57567915106813] and parameters: {'n_components': 32, 'alpha_H': 1.6677615430197892e-05, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.11586905952512971}.
# [I 2025-10-10 17:25:45,613] Trial 20 finished with values: [123369.0957191842, 58.14662801871477] and parameters: {'n_components': 35, 'alpha_H': 0.0007411299781083245, 'alpha_W': 9.833181933644887e-05, 'l1_ratio': 0.06355835028602363}.
# [I 2025-10-10 17:25:46,820] Trial 21 finished with values: [161709.13200594223, 148.39052308385902] and parameters: {'n_components': 14, 'alpha_H': 9.452571391072311e-05, 'alpha_W': 0.0015446089075047066, 'l1_ratio': 0.6375574713552131}.
# [I 2025-10-10 17:25:48,413] Trial 22 finished with values: [120697.33056304083, 45.849575667478994] and parameters: {'n_components': 36, 'alpha_H': 0.00026100256506134736, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}.
# [I 2025-10-10 17:25:49,878] Trial 23 finished with values: [129617.62699890029, 64.26389209787126] and parameters: {'n_components': 31, 'alpha_H': 0.0004828715216179208, 'alpha_W': 0.002055424552015075, 'l1_ratio': 0.49379559636439074}.
# [I 2025-10-10 17:25:50,989] Trial 24 finished with values: [142910.11915311828, 71.80145399713177] and parameters: {'n_components': 22, 'alpha_H': 0.00019170041589170651, 'alpha_W': 1.1919481947918725e-05, 'l1_ratio': 0.10789142699330445}.
# [I 2025-10-10 17:25:51,294] Trial 25 finished with values: [206644.86305313546, 1893.5915773651345] and parameters: {'n_components': 3, 'alpha_H': 0.0008113929572637835, 'alpha_W': 8.771380343280557e-05, 'l1_ratio': 0.5085706911647028}.
# [I 2025-10-10 17:25:52,638] Trial 26 finished with values: [121184.28404360083, 49.11620125034038] and parameters: {'n_components': 37, 'alpha_H': 5.59598687800608e-05, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.7555511385430487}.
# [I 2025-10-10 17:25:53,407] Trial 27 finished with values: [172257.1395836692, 240.11785907843992] and parameters: {'n_components': 10, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 7.40038575908737e-05, 'l1_ratio': 0.16122128725400442}.
# [I 2025-10-10 17:25:54,994] Trial 28 finished with values: [121152.73924515495, 53.60363587642515] and parameters: {'n_components': 38, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.000794714742465374, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:25:56,047] Trial 29 finished with values: [126965.59986468125, 48.297479394535515] and parameters: {'n_components': 33, 'alpha_H': 3.6283583803549155e-05, 'alpha_W': 0.004760767751809498, 'l1_ratio': 0.5393422419156507}.
# [I 2025-10-10 17:25:57,427] Trial 30 finished with values: [127376.65590226746, 57.96870435208577] and parameters: {'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 8.995191735587162e-05, 'l1_ratio': 0.11005192452767676}.
# [I 2025-10-10 17:25:58,170] Trial 31 finished with values: [172768.03653628076, 208.02414695509475] and parameters: {'n_components': 10, 'alpha_H': 0.00019112758217777883, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.8607305832563434}.
# [I 2025-10-10 17:25:58,537] Trial 32 finished with values: [229394.6030829334, 3061.007234868888] and parameters: {'n_components': 2, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.22210781047073025}.
# [I 2025-10-10 17:25:59,241] Trial 33 finished with values: [187739.42730185587, 522.6047221404698] and parameters: {'n_components': 6, 'alpha_H': 0.00010300196600986775, 'alpha_W': 0.0067410742656406975, 'l1_ratio': 0.32320293202075523}.
# [I 2025-10-10 17:26:00,573] Trial 34 finished with values: [143057.053354348, 87.8737395996904] and parameters: {'n_components': 22, 'alpha_H': 0.0012854549964879019, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}.
# [I 2025-10-10 17:26:01,934] Trial 35 finished with values: [118139.07236406431, 44.11683207192527] and parameters: {'n_components': 39, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:26:02,950] Trial 36 finished with values: [162630.90387199903, 147.4570817484126] and parameters: {'n_components': 13, 'alpha_H': 1.2902113024567147e-05, 'alpha_W': 0.0006740513796374046, 'l1_ratio': 0.5026790232288615}.
# [I 2025-10-10 17:26:03,672] Trial 37 finished with values: [198451.0390174162, 1106.205514071215] and parameters: {'n_components': 4, 'alpha_H': 6.853925708853055e-05, 'alpha_W': 0.0053063715752208465, 'l1_ratio': 0.23956189066697242}.
# [I 2025-10-10 17:26:04,688] Trial 38 finished with values: [183488.70796751505, 403.8629547364832] and parameters: {'n_components': 7, 'alpha_H': 0.0002940074130903306, 'alpha_W': 0.009056311714376347, 'l1_ratio': 0.2420552715115004}.
# [I 2025-10-10 17:26:05,998] Trial 39 finished with values: [133103.14805949543, 69.71925420328485] and parameters: {'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}.
# [I 2025-10-10 17:26:07,003] Trial 40 finished with values: [155370.66621422704, 109.8039943096751] and parameters: {'n_components': 16, 'alpha_H': 0.0007887102624766477, 'alpha_W': 0.0007954064937683932, 'l1_ratio': 0.5357746840747585}.
# [I 2025-10-10 17:26:07,538] Trial 41 finished with values: [192917.93689105273, 714.9984103154268] and parameters: {'n_components': 5, 'alpha_H': 0.0032055863990707507, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.18651851039985423}.
# [I 2025-10-10 17:26:07,862] Trial 42 finished with values: [206558.42002747685, 1896.3757172840403] and parameters: {'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:26:09,042] Trial 43 finished with values: [144286.6354939611, 87.09156284565425] and parameters: {'n_components': 21, 'alpha_H': 4.7806541413289224e-05, 'alpha_W': 0.0008620220426018044, 'l1_ratio': 0.17436642900499144}.
# [I 2025-10-10 17:26:10,759] Trial 44 finished with values: [133568.5847697885, 60.42206975423564] and parameters: {'n_components': 28, 'alpha_H': 0.0001446125682015214, 'alpha_W': 0.006459367085984857, 'l1_ratio': 0.13752094414599325}.
# [I 2025-10-10 17:26:11,738] Trial 45 finished with values: [157141.8181074538, 134.60708811636465] and parameters: {'n_components': 15, 'alpha_H': 2.1898812429056927e-05, 'alpha_W': 0.0059440281134109305, 'l1_ratio': 0.877339353380981}.
# [I 2025-10-10 17:26:12,779] Trial 46 finished with values: [167651.71254257706, 175.35157263685477] and parameters: {'n_components': 12, 'alpha_H': 0.0009548873458201665, 'alpha_W': 0.0028292192255361887, 'l1_ratio': 0.5552008115994623}.
# [I 2025-10-10 17:26:13,946] Trial 47 finished with values: [142597.95028419083, 79.2571873786625] and parameters: {'n_components': 22, 'alpha_H': 5.3156560571583175e-05, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.8972157579533268}.
# [I 2025-10-10 17:26:15,519] Trial 48 finished with values: [121436.37517081945, 49.71434417799804] and parameters: {'n_components': 37, 'alpha_H': 0.0007930569433855138, 'alpha_W': 0.00010401341922663452, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:26:16,912] Trial 49 finished with values: [135330.7122949668, 60.61995195592546] and parameters: {'n_components': 30, 'alpha_H': 0.004912819179585588, 'alpha_W': 0.004584154780136381, 'l1_ratio': 0.7798755458576239}.
# [I 2025-10-10 17:26:18,097] Trial 50 finished with values: [134375.07770938607, 61.18358376932959] and parameters: {'n_components': 27, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.002055424552015075, 'l1_ratio': 0.49379559636439074}.
# [I 2025-10-10 17:26:19,352] Trial 51 finished with values: [144142.960822528, 99.9560443939188] and parameters: {'n_components': 21, 'alpha_H': 4.7806541413289224e-05, 'alpha_W': 1.7882156647879485e-05, 'l1_ratio': 0.17436642900499144}.
# [I 2025-10-10 17:26:20,517] Trial 52 finished with values: [142559.38514631713, 79.64285966069713] and parameters: {'n_components': 22, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 1.1919481947918725e-05, 'l1_ratio': 0.16162871409461377}.
# [I 2025-10-10 17:26:21,982] Trial 53 finished with values: [120874.10819296015, 48.77155637573199] and parameters: {'n_components': 37, 'alpha_H': 1.2902113024567147e-05, 'alpha_W': 0.0006596099207886098, 'l1_ratio': 0.009197051616629648}.
# [I 2025-10-10 17:26:23,368] Trial 54 finished with values: [137285.63756614528, 76.71237470322446] and parameters: {'n_components': 25, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.1014715428660321}.
# [I 2025-10-10 17:26:23,816] Trial 55 finished with values: [192348.81883797314, 707.8192809941693] and parameters: {'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.32533033076326434}.
# [I 2025-10-10 17:26:25,385] Trial 56 finished with values: [119201.23264011214, 44.823626939759244] and parameters: {'n_components': 38, 'alpha_H': 0.0009783749110062348, 'alpha_W': 1.0355826161899173e-05, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:26:26,347] Trial 57 finished with values: [162640.53519021632, 169.8192564910148] and parameters: {'n_components': 13, 'alpha_H': 3.0368556852449644e-05, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}.
# [I 2025-10-10 17:26:27,337] Trial 58 finished with values: [155455.9570954002, 134.57154039643888] and parameters: {'n_components': 16, 'alpha_H': 0.00044279363365000874, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.6918951976926933}.
# [I 2025-10-10 17:26:28,519] Trial 59 finished with values: [134090.39675688496, 64.31520207295192] and parameters: {'n_components': 27, 'alpha_H': 0.00019112758217777883, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.22426930946055978}.
# [I 2025-10-10 17:26:28,809] Trial 60 finished with values: [206735.24835565744, 1900.0435230066378] and parameters: {'n_components': 3, 'alpha_H': 0.001369423146002436, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:26:30,083] Trial 61 finished with values: [167817.42558848445, 207.18652702361493] and parameters: {'n_components': 11, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.3253996981592677}.
# [I 2025-10-10 17:26:31,296] Trial 62 finished with values: [130006.48532856825, 54.357829329081916] and parameters: {'n_components': 31, 'alpha_H': 0.0004828715216179208, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.49379559636439074}.
# [I 2025-10-10 17:26:32,715] Trial 63 finished with values: [128440.58576824705, 46.966204004161135] and parameters: {'n_components': 31, 'alpha_H': 0.0008889937283707153, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:26:33,775] Trial 64 finished with values: [144207.03544561338, 80.07686802555149] and parameters: {'n_components': 22, 'alpha_H': 0.00042470585622618684, 'alpha_W': 0.0035291509251299, 'l1_ratio': 0.8021969807540397}.
# [I 2025-10-10 17:26:35,158] Trial 65 finished with values: [138744.51659081585, 81.9371087359953] and parameters: {'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:26:36,515] Trial 66 finished with values: [126775.13762441112, 60.26861411141509] and parameters: {'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}.
# [I 2025-10-10 17:26:37,146] Trial 67 finished with values: [198332.6861085602, 1111.3112722744668] and parameters: {'n_components': 4, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:26:38,353] Trial 68 finished with values: [134295.9214717984, 61.15596377785397] and parameters: {'n_components': 27, 'alpha_H': 0.0012854549964879019, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5683086033354716}.
# [I 2025-10-10 17:26:39,912] Trial 69 finished with values: [150397.01038255135, 108.34903948944707] and parameters: {'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:26:41,084] Trial 70 finished with values: [142528.2727995926, 79.28853213684836] and parameters: {'n_components': 22, 'alpha_H': 1.9099601385505377e-05, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}.
# [I 2025-10-10 17:26:42,116] Trial 71 finished with values: [126707.41781183105, 53.54384501821948] and parameters: {'n_components': 33, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 0.004760767751809498, 'l1_ratio': 0.5393422419156507}.
# [I 2025-10-10 17:26:42,796] Trial 72 finished with values: [187668.3679281778, 524.4263027837261] and parameters: {'n_components': 6, 'alpha_H': 0.00019112758217777883, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.3677158030594335}.
# [I 2025-10-10 17:26:43,612] Trial 73 finished with values: [178964.86607051388, 357.3095678187624] and parameters: {'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}.
# [I 2025-10-10 17:26:43,902] Trial 74 finished with values: [206558.42002747685, 1896.3757172840403] and parameters: {'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:26:45,109] Trial 75 finished with values: [129343.62827946295, 59.95277186269839] and parameters: {'n_components': 31, 'alpha_H': 0.004835952776465951, 'alpha_W': 6.246073681318086e-05, 'l1_ratio': 0.9218742350231168}.
# [I 2025-10-10 17:26:46,198] Trial 76 finished with values: [168335.93615229666, 192.51814843537306] and parameters: {'n_components': 11, 'alpha_H': 0.00829911273846603, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.3930977246667604}.
# [I 2025-10-10 17:26:47,545] Trial 77 finished with values: [121218.95575822907, 45.632047577801124] and parameters: {'n_components': 36, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.6311386259972629}.
# [I 2025-10-10 17:26:48,999] Trial 78 finished with values: [120619.52299488617, 44.90711059124912] and parameters: {'n_components': 36, 'alpha_H': 0.00026100256506134736, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.7948113035416484}.
# [I 2025-10-10 17:26:50,191] Trial 79 finished with values: [133205.75548496592, 65.27596447565438] and parameters: {'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.5026370931051921}.
# [I 2025-10-10 17:26:51,092] Trial 80 finished with values: [172856.613739304, 247.2851582589572] and parameters: {'n_components': 10, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.0005379125214937586, 'l1_ratio': 0.16122128725400442}.
# [I 2025-10-10 17:26:51,959] Trial 81 finished with values: [162717.8088405102, 163.8485784340935] and parameters: {'n_components': 13, 'alpha_H': 1.9634341572933338e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.5026790232288615}.
# [I 2025-10-10 17:26:52,776] Trial 82 finished with values: [180037.96025806357, 359.38856521107886] and parameters: {'n_components': 8, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.000794714742465374, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:26:53,969] Trial 83 finished with values: [132865.42006832827, 67.56451326421421] and parameters: {'n_components': 28, 'alpha_H': 0.0003002984436915126, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.1952429877980445}.
# [I 2025-10-10 17:26:55,368] Trial 84 finished with values: [128654.54059893097, 62.709699037637705] and parameters: {'n_components': 30, 'alpha_H': 0.00010300196600986775, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:26:56,431] Trial 85 finished with values: [143121.40387504085, 79.55410151762149] and parameters: {'n_components': 22, 'alpha_H': 0.0007930569433855138, 'alpha_W': 6.955319544158292e-05, 'l1_ratio': 0.8972157579533268}.
# [I 2025-10-10 17:26:57,396] Trial 86 finished with values: [166339.25595469063, 178.54718619220648] and parameters: {'n_components': 12, 'alpha_H': 1.1828996391101272e-05, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.6454722959071678}.
# [I 2025-10-10 17:26:57,796] Trial 87 finished with values: [229926.98822877964, 3063.878399291946] and parameters: {'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 3.398850311078452e-05, 'l1_ratio': 0.9404585843529143}.
# [I 2025-10-10 17:26:59,152] Trial 88 finished with values: [118153.53983846516, 45.3873930029567] and parameters: {'n_components': 39, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:26:59,783] Trial 89 finished with values: [198704.7139156632, 1108.9003030440442] and parameters: {'n_components': 4, 'alpha_H': 0.0001446125682015214, 'alpha_W': 0.006459367085984857, 'l1_ratio': 0.9539285770025874}.
# [I 2025-10-10 17:27:00,961] Trial 90 finished with values: [155023.30234938095, 135.55750454751168] and parameters: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5986584841970366}.
# [I 2025-10-10 17:27:02,363] Trial 91 finished with values: [132843.39176197018, 65.2512209484564] and parameters: {'n_components': 28, 'alpha_H': 0.0008113929572637835, 'alpha_W': 8.771380343280557e-05, 'l1_ratio': 0.5085706911647028}.
# [I 2025-10-10 17:27:02,719] Trial 92 finished with values: [229958.69755261944, 3066.8135962580636] and parameters: {'n_components': 2, 'alpha_H': 0.005553837526912238, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:27:03,349] Trial 93 finished with values: [199278.59143259935, 1111.395248691065] and parameters: {'n_components': 4, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:27:04,493] Trial 94 finished with values: [153267.45513547986, 104.63711666218279] and parameters: {'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}.
# [I 2025-10-10 17:27:05,804] Trial 95 finished with values: [137190.11505355372, 76.7934262594072] and parameters: {'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}.
# [I 2025-10-10 17:27:06,765] Trial 96 finished with values: [162766.20325140603, 161.94009367905736] and parameters: {'n_components': 13, 'alpha_H': 0.00012896625857891436, 'alpha_W': 1.1126788925493283e-05, 'l1_ratio': 0.2912291401980419}.
# [I 2025-10-10 17:27:08,333] Trial 97 finished with values: [121436.37517081945, 49.71434417799804] and parameters: {'n_components': 37, 'alpha_H': 0.0007930569433855138, 'alpha_W': 0.00010401341922663452, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:27:09,794] Trial 98 finished with values: [119447.53704083824, 46.70502168013294] and parameters: {'n_components': 39, 'alpha_H': 0.00010300196600986775, 'alpha_W': 0.0067410742656406975, 'l1_ratio': 0.32320293202075523}.
# [I 2025-10-10 17:27:11,376] Trial 99 finished with values: [119664.79212328445, 54.19514100573214] and parameters: {'n_components': 38, 'alpha_H': 0.00019255395572015605, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.4401524937396013}.
# Número de soluções no Pareto front: 43
#
# ➡️ Soluções ótimas (compromissos KL vs Calinski):
# KL=157641.71, Calinski=136.70, Params={'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}
# KL=178964.87, Calinski=357.31, Params={'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}
# KL=162861.22, Calinski=173.21, Params={'n_components': 13, 'alpha_H': 0.00037520558551242813, 'alpha_W': 0.00019762189340280086, 'l1_ratio': 0.2912291401980419}
# KL=137190.12, Calinski=76.79, Params={'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}
# KL=187549.82, Calinski=524.56, Params={'n_components': 6, 'alpha_H': 0.0003058656666978527, 'alpha_W': 1.2681352169084594e-05, 'l1_ratio': 0.9093204020787821}
# KL=192338.78, Calinski=708.69, Params={'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 1.3667272915456215e-05, 'l1_ratio': 0.32533033076326434}
# KL=199925.31, Calinski=1124.43, Params={'n_components': 4, 'alpha_H': 0.009133995846860976, 'alpha_W': 0.0020736445177905022, 'l1_ratio': 0.1987156815341724}
# KL=230050.99, Calinski=3068.79, Params={'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}
# KL=123369.10, Calinski=58.15, Params={'n_components': 35, 'alpha_H': 0.0007411299781083245, 'alpha_W': 9.833181933644887e-05, 'l1_ratio': 0.06355835028602363}
# KL=161709.13, Calinski=148.39, Params={'n_components': 14, 'alpha_H': 9.452571391072311e-05, 'alpha_W': 0.0015446089075047066, 'l1_ratio': 0.6375574713552131}
# KL=129617.63, Calinski=64.26, Params={'n_components': 31, 'alpha_H': 0.0004828715216179208, 'alpha_W': 0.002055424552015075, 'l1_ratio': 0.49379559636439074}
# KL=172257.14, Calinski=240.12, Params={'n_components': 10, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 7.40038575908737e-05, 'l1_ratio': 0.16122128725400442}
# KL=229394.60, Calinski=3061.01, Params={'n_components': 2, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.22210781047073025}
# KL=143057.05, Calinski=87.87, Params={'n_components': 22, 'alpha_H': 0.0012854549964879019, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}
# KL=118139.07, Calinski=44.12, Params={'n_components': 39, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=183488.71, Calinski=403.86, Params={'n_components': 7, 'alpha_H': 0.0002940074130903306, 'alpha_W': 0.009056311714376347, 'l1_ratio': 0.2420552715115004}
# KL=133103.15, Calinski=69.72, Params={'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}
# KL=192917.94, Calinski=715.00, Params={'n_components': 5, 'alpha_H': 0.0032055863990707507, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.18651851039985423}
# KL=206558.42, Calinski=1896.38, Params={'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=144142.96, Calinski=99.96, Params={'n_components': 21, 'alpha_H': 4.7806541413289224e-05, 'alpha_W': 1.7882156647879485e-05, 'l1_ratio': 0.17436642900499144}
# KL=162640.54, Calinski=169.82, Params={'n_components': 13, 'alpha_H': 3.0368556852449644e-05, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}
# KL=206735.25, Calinski=1900.04, Params={'n_components': 3, 'alpha_H': 0.001369423146002436, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=167817.43, Calinski=207.19, Params={'n_components': 11, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.3253996981592677}
# KL=138744.52, Calinski=81.94, Params={'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}
# KL=126775.14, Calinski=60.27, Params={'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}
# KL=198332.69, Calinski=1111.31, Params={'n_components': 4, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=150397.01, Calinski=108.35, Params={'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.5142344384136116}
# KL=178964.87, Calinski=357.31, Params={'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}
# KL=206558.42, Calinski=1896.38, Params={'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=172856.61, Calinski=247.29, Params={'n_components': 10, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.0005379125214937586, 'l1_ratio': 0.16122128725400442}
# KL=180037.96, Calinski=359.39, Params={'n_components': 8, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.000794714742465374, 'l1_ratio': 0.8714605901877177}
# KL=132865.42, Calinski=67.56, Params={'n_components': 28, 'alpha_H': 0.0003002984436915126, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.1952429877980445}
# KL=128654.54, Calinski=62.71, Params={'n_components': 30, 'alpha_H': 0.00010300196600986775, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}
# KL=166339.26, Calinski=178.55, Params={'n_components': 12, 'alpha_H': 1.1828996391101272e-05, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.6454722959071678}
# KL=229926.99, Calinski=3063.88, Params={'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 3.398850311078452e-05, 'l1_ratio': 0.9404585843529143}
# KL=118153.54, Calinski=45.39, Params={'n_components': 39, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=155023.30, Calinski=135.56, Params={'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5986584841970366}
# KL=132843.39, Calinski=65.25, Params={'n_components': 28, 'alpha_H': 0.0008113929572637835, 'alpha_W': 8.771380343280557e-05, 'l1_ratio': 0.5085706911647028}
# KL=229958.70, Calinski=3066.81, Params={'n_components': 2, 'alpha_H': 0.005553837526912238, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.3492095746126609}
# KL=199278.59, Calinski=1111.40, Params={'n_components': 4, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}
# KL=137190.12, Calinski=76.79, Params={'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}
# KL=119447.54, Calinski=46.71, Params={'n_components': 39, 'alpha_H': 0.00010300196600986775, 'alpha_W': 0.0067410742656406975, 'l1_ratio': 0.32320293202075523}
# KL=119664.79, Calinski=54.20, Params={'n_components': 38, 'alpha_H': 0.00019255395572015605, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.4401524937396013}
#
# ➡️ Solução mais equilibrada escolhida automaticamente:
# KL=157641.71, Calinski=136.70
# Parâmetros: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}

# %%
nmf_best = NMF(
    n_components=best_params["n_components"],
    init="nndsvda",
    solver="mu",
    beta_loss="kullback-leibler",
    max_iter=MAX_ITER,
    random_state=SEED,
    alpha_H=best_params["alpha_H"],
    alpha_W=best_params["alpha_W"],
    l1_ratio=best_params["l1_ratio"]
)

W_best = nmf_best.fit_transform(X.values)
H_best = nmf_best.components_

# Guardar em DataFrames
df_W = pd.DataFrame(W_best, index=X.index, columns=[f"padrao_{i+1}" for i in range(W_best.shape[1])])
df_H = pd.DataFrame(H_best, columns=X.columns, index=[f"padrao_{i+1}" for i in range(H_best.shape[0])])

print(f"✅ df_W e df_H prontos com Optuna (K={best_params['n_components']})")
# Out:
# ✅ df_W e df_H prontos com Optuna (K=16)

# %%
# ==== Reconstrução final ====
X_hat = W_best @ H_best

# ==== Métricas de erro (NMF final, KL) ====

# Divergência KL
mask = X.values > 0
kl_div = np.sum(
    X.values[mask] * np.log(X.values[mask] / np.maximum(X_hat[mask], 1e-10))
    - X.values[mask] + X_hat[mask]
)

# RMSE e MAE auxiliares
diff = X.values - X_hat
rmse = np.sqrt((diff ** 2).mean())
mae  = np.abs(diff).mean()

print(f"Divergência KL: {kl_div:.6f}")
print(f"RMSE: {rmse:.6f}, MAE: {mae:.6f}")
# Out:
# Divergência KL: 157641.710671
# RMSE: 0.761435, MAE: 0.124900

# %%
df_W.head()
# Out:
#                               padrao_1       padrao_2       padrao_3  \
# timestamp
# 1900-01-01 00:00:00.852  8.795910e-175   0.000000e+00  7.816144e-113
# 1900-01-01 00:00:03.401  2.008556e-118   0.000000e+00   1.043267e-65
# 1900-01-01 00:00:05.246  1.765179e-110  5.427120e-160  7.141552e-164
# 1900-01-01 00:00:07.974   0.000000e+00   0.000000e+00   1.647845e+00
# 1900-01-01 00:00:08.614   6.948457e-01   1.020781e-31   0.000000e+00
#
#                               padrao_4      padrao_5      padrao_6  \
# timestamp
# 1900-01-01 00:00:00.852  3.312757e-105  2.417460e+00  0.000000e+00
# 1900-01-01 00:00:03.401   1.591409e-48  3.071561e-63  0.000000e+00
# 1900-01-01 00:00:05.246  2.086757e-134  1.303124e-48  3.142231e+00
# 1900-01-01 00:00:07.974   1.380885e-72  2.770991e-98  0.000000e+00
# 1900-01-01 00:00:08.614   3.975726e-01  0.000000e+00  5.382901e-26
#
#                               padrao_7       padrao_8       padrao_9  \
# timestamp
# 1900-01-01 00:00:00.852  1.842526e-295   2.031529e-93  8.003952e-111
# 1900-01-01 00:00:03.401  1.011227e-114   7.682763e-40   8.999235e-01
# 1900-01-01 00:00:05.246   0.000000e+00   1.855168e-58   4.940969e-01
# 1900-01-01 00:00:07.974  1.895330e-107   0.000000e+00  1.461044e-114
# 1900-01-01 00:00:08.614   3.525701e-01  5.852338e-118  1.581834e-101
#
#                              padrao_10      padrao_11     padrao_12  \
# timestamp
# 1900-01-01 00:00:00.852  2.114985e-156   5.547209e-01  1.653891e-22
# 1900-01-01 00:00:03.401   2.643491e-01   4.876895e-76  0.000000e+00
# 1900-01-01 00:00:05.246   5.084288e-57  3.468446e-154  4.577991e-16
# 1900-01-01 00:00:07.974   2.536591e-79   2.911625e-26  1.563063e-13
# 1900-01-01 00:00:08.614   0.000000e+00   1.249196e-55  1.842912e-79
#
#                              padrao_13      padrao_14      padrao_15  \
# timestamp
# 1900-01-01 00:00:00.852   0.000000e+00   0.000000e+00   0.000000e+00
# 1900-01-01 00:00:03.401   2.480880e-44   0.000000e+00  1.708660e-103
# 1900-01-01 00:00:05.246   0.000000e+00   0.000000e+00   1.813613e-93
# 1900-01-01 00:00:07.974  7.553630e-298  1.764106e-109   9.031715e-95
# 1900-01-01 00:00:08.614   3.746755e-01   0.000000e+00   4.203163e-01
#
#                              padrao_16
# timestamp
# 1900-01-01 00:00:00.852   9.030050e-60
# 1900-01-01 00:00:03.401   1.659116e+00
# 1900-01-01 00:00:05.246   1.218121e-78
# 1900-01-01 00:00:07.974  8.373649e-152
# 1900-01-01 00:00:08.614   0.000000e+00

# %%
df_W.to_csv("nmf_W.csv")
