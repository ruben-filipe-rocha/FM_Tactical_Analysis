# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import (
    silhouette_score,
    davies_bouldin_score,
    calinski_harabasz_score,
    pairwise_distances_argmin_min
)

from tqdm.notebook import tqdm
from scipy.ndimage import gaussian_filter1d

# %%
# ==== 0) Parâmetros ====
ARQ_IN    = "Matrix_X_Typical_set.csv"        # saída do passo anterior (pivot pronto)
OUT_W     = "W_frames.csv"      # pesos por frame (frames × K)
OUT_H     = "H_padroes.csv"     # padrões (K × células)
OUT_TOP   = "NMF_W_TS.csv"
SEED      = 42
MAX_ITER  = 2000

# ==== 1) Ler matriz ====
X = pd.read_csv(ARQ_IN, index_col=0)
X = X.clip(lower=0).astype(float)

# %%
print(f"Dimensões da matriz X: {X.shape}")  # (n_frames, n_cells)
# Out:
# Dimensões da matriz X: (850, 1075)

# %%
# ==== 4) Optimização com Optuna (multi-objetivo: KL + Calinski) ====
import optuna
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import calinski_harabasz_score

def objective(trial):
    # pesquisar nº de componentes (fatores latentes)
    n_components = trial.suggest_int("n_components", 2, min(40, X.shape[1]))

    alpha_H = trial.suggest_float("alpha_H", 1e-5, 1e-2, log=True)
    alpha_W = trial.suggest_float("alpha_W", 1e-5, 1e-2, log=True)
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    nmf = NMF(
        n_components=n_components,
        init="nndsvda",
        solver="mu",
        beta_loss="kullback-leibler",
        max_iter=MAX_ITER,
        random_state=SEED,
        alpha_H=alpha_H,
        alpha_W=alpha_W,
        l1_ratio=l1_ratio
    )

    W = nmf.fit_transform(X.values)
    H = nmf.components_
    X_hat = W @ H

    # ----------------
    # 1. Divergência KL ↓
    # ----------------
    mask = X.values > 0
    kl = np.sum(
        X.values[mask] * np.log(X.values[mask] / np.maximum(X_hat[mask], 1e-10))
        - X.values[mask] + X_hat[mask]
    )

    # ----------------
    # 2. Calinski-Harabasz ↑
    # ----------------
    scaler = StandardScaler()
    W_scaled = scaler.fit_transform(W)

    kmeans = KMeans(n_clusters=n_components, random_state=SEED)
    labels = kmeans.fit_predict(W_scaled)

    try:
        calinski = calinski_harabasz_score(W_scaled, labels)
    except Exception:
        calinski = 0

    return kl, calinski


# ==== Multi-Objective Study ====
study = optuna.create_study(
    directions=["minimize", "maximize"],  # KL ↓, Calinski ↑
    sampler=optuna.samplers.NSGAIISampler(seed=SEED)
)

study.optimize(objective, n_trials=100)

# ==== Resultados ====
print("Número de soluções no Pareto front:", len(study.best_trials))
print("\n➡️ Soluções ótimas (compromissos KL vs Calinski):")
for t in study.best_trials:
    vals = t.values
    print(f"KL={vals[0]:.2f}, Calinski={vals[1]:.2f}, Params={t.params}")

# ---- Selecionar 1 solução do Pareto front ----
chosen_trial = study.best_trials[0]
best_params = chosen_trial.params
print("\n➡️ Solução mais equilibrada escolhida automaticamente:")
print(f"KL={chosen_trial.values[0]:.2f}, Calinski={chosen_trial.values[1]:.2f}")
print(f"Parâmetros: {best_params}")
# Out:
# [I 2025-10-10 17:35:47,279] A new study created in memory with name: no-name-67a81be4-9711-4b94-bb80-25fc546b2f15
# [I 2025-10-10 17:35:48,230] Trial 0 finished with values: [137180.11536980403, 132.9922553398635] and parameters: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}.
# [I 2025-10-10 17:35:48,863] Trial 1 finished with values: [156223.34395696846, 328.3689392130336] and parameters: {'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}.
# [I 2025-10-10 17:35:50,244] Trial 2 finished with values: [116797.90959439203, 75.98054789889007] and parameters: {'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 1.1527987128232396e-05, 'l1_ratio': 0.9699098521619943}.
# [I 2025-10-10 17:35:51,482] Trial 3 finished with values: [105398.07143725127, 51.617983261892235] and parameters: {'n_components': 34, 'alpha_H': 4.335281794951564e-05, 'alpha_W': 3.511356313970405e-05, 'l1_ratio': 0.18340450985343382}.
# [I 2025-10-10 17:35:52,335] Trial 4 finished with values: [141294.4378524184, 164.00087385471573] and parameters: {'n_components': 13, 'alpha_H': 0.00037520558551242813, 'alpha_W': 0.00019762189340280086, 'l1_ratio': 0.2912291401980419}.
# [I 2025-10-10 17:35:53,180] Trial 5 finished with values: [116921.12764195976, 85.70611166422853] and parameters: {'n_components': 25, 'alpha_H': 2.621087878265438e-05, 'alpha_W': 7.52374288453485e-05, 'l1_ratio': 0.3663618432936917}.
# [I 2025-10-10 17:35:54,066] Trial 6 finished with values: [127367.74863116592, 108.95656702839257] and parameters: {'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:35:55,448] Trial 7 finished with values: [116592.00947085355, 75.59071188606059] and parameters: {'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}.
# [I 2025-10-10 17:35:55,829] Trial 8 finished with values: [178385.49922513994, 1107.6969988279886] and parameters: {'n_components': 4, 'alpha_H': 0.007025166339242158, 'alpha_W': 0.00788671412999049, 'l1_ratio': 0.8083973481164611}.
# [I 2025-10-10 17:35:56,607] Trial 9 finished with values: [141124.29420383894, 135.42076123203753] and parameters: {'n_components': 13, 'alpha_H': 1.9634341572933338e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.4401524937396013}.
# [I 2025-10-10 17:35:57,328] Trial 10 finished with values: [163045.99556540736, 543.0900364202579] and parameters: {'n_components': 6, 'alpha_H': 0.0003058656666978527, 'alpha_W': 1.2681352169084594e-05, 'l1_ratio': 0.9093204020787821}.
# [I 2025-10-10 17:35:58,310] Trial 11 finished with values: [142320.12020672276, 169.91840883980439] and parameters: {'n_components': 12, 'alpha_H': 0.0009717775305059633, 'alpha_W': 8.612579192594876e-05, 'l1_ratio': 0.5200680211778108}.
# [I 2025-10-10 17:35:59,330] Trial 12 finished with values: [121023.80795479787, 83.78962998905348] and parameters: {'n_components': 23, 'alpha_H': 3.585612610345396e-05, 'alpha_W': 0.008105016126411584, 'l1_ratio': 0.7751328233611146}.
# [I 2025-10-10 17:36:00,597] Trial 13 finished with values: [103062.44734601525, 47.09547282686731] and parameters: {'n_components': 38, 'alpha_H': 0.004835952776465951, 'alpha_W': 0.0006218704727769079, 'l1_ratio': 0.9218742350231168}.
# [I 2025-10-10 17:36:01,069] Trial 14 finished with values: [168854.82503044902, 783.2262318107747] and parameters: {'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 1.3667272915456215e-05, 'l1_ratio': 0.32533033076326434}.
# [I 2025-10-10 17:36:02,054] Trial 15 finished with values: [132512.70520272356, 119.76955876050985] and parameters: {'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}.
# [I 2025-10-10 17:36:02,786] Trial 16 finished with values: [142467.2687428429, 167.18373642913815] and parameters: {'n_components': 12, 'alpha_H': 0.00042470585622618684, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.8021969807540397}.
# [I 2025-10-10 17:36:03,225] Trial 17 finished with values: [176508.10694777506, 1121.8758583495512] and parameters: {'n_components': 4, 'alpha_H': 0.009133995846860976, 'alpha_W': 0.0020736445177905022, 'l1_ratio': 0.1987156815341724}.
# [I 2025-10-10 17:36:03,535] Trial 18 finished with values: [199857.13759842596, 4053.2162531968966] and parameters: {'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:36:04,781] Trial 19 finished with values: [106858.84815618745, 52.01385158671268] and parameters: {'n_components': 32, 'alpha_H': 1.6677615430197892e-05, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.11586905952512971}.
# [I 2025-10-10 17:36:05,857] Trial 20 finished with values: [104175.53571281188, 47.02862793582081] and parameters: {'n_components': 35, 'alpha_H': 0.0007411299781083245, 'alpha_W': 9.833181933644887e-05, 'l1_ratio': 0.06355835028602363}.
# [I 2025-10-10 17:36:06,555] Trial 21 finished with values: [139939.11864600913, 139.22063480075283] and parameters: {'n_components': 14, 'alpha_H': 9.452571391072311e-05, 'alpha_W': 0.0015446089075047066, 'l1_ratio': 0.6375574713552131}.
# [I 2025-10-10 17:36:07,882] Trial 22 finished with values: [103043.1466179341, 50.49774337165449] and parameters: {'n_components': 36, 'alpha_H': 0.00026100256506134736, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}.
# [I 2025-10-10 17:36:09,074] Trial 23 finished with values: [110779.17035930506, 55.62975030964423] and parameters: {'n_components': 31, 'alpha_H': 0.0004828715216179208, 'alpha_W': 0.002055424552015075, 'l1_ratio': 0.49379559636439074}.
# [I 2025-10-10 17:36:10,294] Trial 24 finished with values: [122472.87796400135, 85.96992636809155] and parameters: {'n_components': 22, 'alpha_H': 0.00019170041589170651, 'alpha_W': 1.1919481947918725e-05, 'l1_ratio': 0.10789142699330445}.
# [I 2025-10-10 17:36:10,673] Trial 25 finished with values: [180583.00515517266, 2385.556441337175] and parameters: {'n_components': 3, 'alpha_H': 0.0008113929572637835, 'alpha_W': 8.771380343280557e-05, 'l1_ratio': 0.5085706911647028}.
# [I 2025-10-10 17:36:11,754] Trial 26 finished with values: [102281.37026873257, 48.7584387663685] and parameters: {'n_components': 37, 'alpha_H': 5.59598687800608e-05, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.7555511385430487}.
# [I 2025-10-10 17:36:12,381] Trial 27 finished with values: [149276.56044427305, 244.966949178909] and parameters: {'n_components': 10, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 7.40038575908737e-05, 'l1_ratio': 0.16122128725400442}.
# [I 2025-10-10 17:36:13,473] Trial 28 finished with values: [102875.21141106982, 47.394085100180824] and parameters: {'n_components': 38, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.000794714742465374, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:36:15,115] Trial 29 finished with values: [107160.77919007518, 45.58482533828132] and parameters: {'n_components': 33, 'alpha_H': 3.6283583803549155e-05, 'alpha_W': 0.004760767751809498, 'l1_ratio': 0.5393422419156507}.
# [I 2025-10-10 17:36:16,290] Trial 30 finished with values: [107756.34593269648, 67.96775105000955] and parameters: {'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 8.995191735587162e-05, 'l1_ratio': 0.11005192452767676}.
# [I 2025-10-10 17:36:16,922] Trial 31 finished with values: [149723.11433848256, 198.45796255190706] and parameters: {'n_components': 10, 'alpha_H': 0.00019112758217777883, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.8607305832563434}.
# [I 2025-10-10 17:36:17,251] Trial 32 finished with values: [199292.50847330055, 4049.631428886746] and parameters: {'n_components': 2, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.22210781047073025}.
# [I 2025-10-10 17:36:18,122] Trial 33 finished with values: [163269.31907133845, 543.5166255298584] and parameters: {'n_components': 6, 'alpha_H': 0.00010300196600986775, 'alpha_W': 0.0067410742656406975, 'l1_ratio': 0.32320293202075523}.
# [I 2025-10-10 17:36:19,297] Trial 34 finished with values: [122808.1157272358, 86.49247934427449] and parameters: {'n_components': 22, 'alpha_H': 0.0012854549964879019, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}.
# [I 2025-10-10 17:36:20,365] Trial 35 finished with values: [100164.29208202123, 40.87340056949398] and parameters: {'n_components': 39, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:36:21,170] Trial 36 finished with values: [141093.50513064337, 162.20469079651843] and parameters: {'n_components': 13, 'alpha_H': 1.2902113024567147e-05, 'alpha_W': 0.0006740513796374046, 'l1_ratio': 0.5026790232288615}.
# [I 2025-10-10 17:36:21,615] Trial 37 finished with values: [175277.92679238936, 1106.6429342789097] and parameters: {'n_components': 4, 'alpha_H': 6.853925708853055e-05, 'alpha_W': 0.0053063715752208465, 'l1_ratio': 0.23956189066697242}.
# [I 2025-10-10 17:36:22,374] Trial 38 finished with values: [159596.49419484526, 291.76909206240106] and parameters: {'n_components': 7, 'alpha_H': 0.0002940074130903306, 'alpha_W': 0.009056311714376347, 'l1_ratio': 0.2420552715115004}.
# [I 2025-10-10 17:36:23,319] Trial 39 finished with values: [115020.87979412884, 67.1125345840689] and parameters: {'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}.
# [I 2025-10-10 17:36:24,195] Trial 40 finished with values: [135148.93687005737, 119.13990944744613] and parameters: {'n_components': 16, 'alpha_H': 0.0007887102624766477, 'alpha_W': 0.0007954064937683932, 'l1_ratio': 0.5357746840747585}.
# [I 2025-10-10 17:36:24,639] Trial 41 finished with values: [169265.04244739024, 792.5881476141309] and parameters: {'n_components': 5, 'alpha_H': 0.0032055863990707507, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.18651851039985423}.
# [I 2025-10-10 17:36:24,964] Trial 42 finished with values: [180522.7562517405, 2388.906586665205] and parameters: {'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:36:26,172] Trial 43 finished with values: [124019.74634417669, 69.89188043205729] and parameters: {'n_components': 21, 'alpha_H': 4.7806541413289224e-05, 'alpha_W': 0.0008620220426018044, 'l1_ratio': 0.17436642900499144}.
# [I 2025-10-10 17:36:27,464] Trial 44 finished with values: [115189.06787051524, 61.57101436986426] and parameters: {'n_components': 28, 'alpha_H': 0.0001446125682015214, 'alpha_W': 0.006459367085984857, 'l1_ratio': 0.13752094414599325}.
# [I 2025-10-10 17:36:28,223] Trial 45 finished with values: [136237.42387004872, 131.95694007817005] and parameters: {'n_components': 15, 'alpha_H': 2.1898812429056927e-05, 'alpha_W': 0.0059440281134109305, 'l1_ratio': 0.877339353380981}.
# [I 2025-10-10 17:36:29,039] Trial 46 finished with values: [143291.5759901096, 197.66889165166648] and parameters: {'n_components': 12, 'alpha_H': 0.0009548873458201665, 'alpha_W': 0.0028292192255361887, 'l1_ratio': 0.5552008115994623}.
# [I 2025-10-10 17:36:30,376] Trial 47 finished with values: [122327.47288546994, 75.5921321003459] and parameters: {'n_components': 22, 'alpha_H': 5.3156560571583175e-05, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.8972157579533268}.
# [I 2025-10-10 17:36:31,879] Trial 48 finished with values: [102305.19797113445, 42.94702596846749] and parameters: {'n_components': 37, 'alpha_H': 0.0007930569433855138, 'alpha_W': 0.00010401341922663452, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:36:33,048] Trial 49 finished with values: [116301.70893142393, 56.34423724727238] and parameters: {'n_components': 30, 'alpha_H': 0.004912819179585588, 'alpha_W': 0.004584154780136381, 'l1_ratio': 0.7798755458576239}.
# [I 2025-10-10 17:36:34,332] Trial 50 finished with values: [113718.11767805155, 63.00613895493483] and parameters: {'n_components': 27, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.11586905952512971}.
# [I 2025-10-10 17:36:35,345] Trial 51 finished with values: [124121.01941232877, 76.37918274161534] and parameters: {'n_components': 21, 'alpha_H': 4.7806541413289224e-05, 'alpha_W': 1.7882156647879485e-05, 'l1_ratio': 0.17436642900499144}.
# [I 2025-10-10 17:36:36,494] Trial 52 finished with values: [122288.2707354448, 86.59179064266198] and parameters: {'n_components': 22, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 1.1919481947918725e-05, 'l1_ratio': 0.16162871409461377}.
# [I 2025-10-10 17:36:37,496] Trial 53 finished with values: [102289.81692563204, 45.354715394851894] and parameters: {'n_components': 37, 'alpha_H': 1.2902113024567147e-05, 'alpha_W': 0.0006596099207886098, 'l1_ratio': 0.009197051616629648}.
# [I 2025-10-10 17:36:38,345] Trial 54 finished with values: [117055.10206461188, 78.20912401977489] and parameters: {'n_components': 25, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.1014715428660321}.
# [I 2025-10-10 17:36:38,783] Trial 55 finished with values: [168867.11101223313, 786.0826800695403] and parameters: {'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.32533033076326434}.
# [I 2025-10-10 17:36:39,941] Trial 56 finished with values: [101265.14907742296, 49.45885579394274] and parameters: {'n_components': 38, 'alpha_H': 0.0009783749110062348, 'alpha_W': 1.0355826161899173e-05, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:36:40,867] Trial 57 finished with values: [141104.238929588, 162.21234818086654] and parameters: {'n_components': 13, 'alpha_H': 3.0368556852449644e-05, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}.
# [I 2025-10-10 17:36:42,039] Trial 58 finished with values: [135070.3524629297, 106.95637233320382] and parameters: {'n_components': 16, 'alpha_H': 0.00044279363365000874, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.6918951976926933}.
# [I 2025-10-10 17:36:43,469] Trial 59 finished with values: [113808.46514418996, 62.45662080776443] and parameters: {'n_components': 27, 'alpha_H': 0.00019112758217777883, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.22426930946055978}.
# [I 2025-10-10 17:36:43,798] Trial 60 finished with values: [180661.52276606552, 2391.1369474893336] and parameters: {'n_components': 3, 'alpha_H': 0.001369423146002436, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:36:44,617] Trial 61 finished with values: [146160.17069396834, 212.12109251898713] and parameters: {'n_components': 11, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.3253996981592677}.
# [I 2025-10-10 17:36:45,752] Trial 62 finished with values: [111041.15875777682, 56.49925702253227] and parameters: {'n_components': 31, 'alpha_H': 0.0004828715216179208, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.49379559636439074}.
# [I 2025-10-10 17:36:46,860] Trial 63 finished with values: [109864.15854258733, 57.57269013146243] and parameters: {'n_components': 31, 'alpha_H': 0.0008889937283707153, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:36:48,126] Trial 64 finished with values: [123646.75096030139, 75.26905027673654] and parameters: {'n_components': 22, 'alpha_H': 0.00042470585622618684, 'alpha_W': 0.0035291509251299, 'l1_ratio': 0.8021969807540397}.
# [I 2025-10-10 17:36:49,233] Trial 65 finished with values: [118130.78040528105, 83.64959126747873] and parameters: {'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:36:50,694] Trial 66 finished with values: [107069.43190297822, 55.02958940791985] and parameters: {'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}.
# [I 2025-10-10 17:36:51,145] Trial 67 finished with values: [175218.12390876448, 1117.2903773225064] and parameters: {'n_components': 4, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:36:52,101] Trial 68 finished with values: [114438.12576494449, 59.23559261591896] and parameters: {'n_components': 27, 'alpha_H': 0.0012854549964879019, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5683086033354716}.
# [I 2025-10-10 17:36:52,959] Trial 69 finished with values: [127468.86815959097, 108.86944435174533] and parameters: {'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:36:54,262] Trial 70 finished with values: [122272.77399289899, 86.26646822961592] and parameters: {'n_components': 22, 'alpha_H': 1.9099601385505377e-05, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}.
# [I 2025-10-10 17:36:55,593] Trial 71 finished with values: [106959.42343796843, 58.32580077556516] and parameters: {'n_components': 33, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 0.004760767751809498, 'l1_ratio': 0.5393422419156507}.
# [I 2025-10-10 17:36:56,294] Trial 72 finished with values: [163202.2101225775, 543.6516463369787] and parameters: {'n_components': 6, 'alpha_H': 0.00019112758217777883, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.3677158030594335}.
# [I 2025-10-10 17:36:57,222] Trial 73 finished with values: [156223.34395696846, 328.3689392130336] and parameters: {'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}.
# [I 2025-10-10 17:36:57,686] Trial 74 finished with values: [180522.7562517405, 2388.906586665205] and parameters: {'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}.
# [I 2025-10-10 17:36:59,004] Trial 75 finished with values: [110365.21881439672, 56.84626152356021] and parameters: {'n_components': 31, 'alpha_H': 0.004835952776465951, 'alpha_W': 6.246073681318086e-05, 'l1_ratio': 0.9218742350231168}.
# [I 2025-10-10 17:36:59,995] Trial 76 finished with values: [146779.71584040584, 213.79238352601482] and parameters: {'n_components': 11, 'alpha_H': 0.00829911273846603, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.3930977246667604}.
# [I 2025-10-10 17:37:01,504] Trial 77 finished with values: [103406.16719433648, 48.237799555710104] and parameters: {'n_components': 36, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.6311386259972629}.
# [I 2025-10-10 17:37:02,690] Trial 78 finished with values: [103120.67188447417, 46.4253066529296] and parameters: {'n_components': 36, 'alpha_H': 0.00026100256506134736, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.7948113035416484}.
# [I 2025-10-10 17:37:03,985] Trial 79 finished with values: [114755.74359029242, 69.21058251130724] and parameters: {'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.5026370931051921}.
# [I 2025-10-10 17:37:04,810] Trial 80 finished with values: [149968.1914762404, 254.21349796953933] and parameters: {'n_components': 10, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.0005379125214937586, 'l1_ratio': 0.16122128725400442}.
# [I 2025-10-10 17:37:05,593] Trial 81 finished with values: [141125.03013743338, 161.97851024654878] and parameters: {'n_components': 13, 'alpha_H': 1.9634341572933338e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.5026790232288615}.
# [I 2025-10-10 17:37:06,238] Trial 82 finished with values: [157115.49199652395, 254.5118809197201] and parameters: {'n_components': 8, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.000794714742465374, 'l1_ratio': 0.8714605901877177}.
# [I 2025-10-10 17:37:07,464] Trial 83 finished with values: [114492.6330916158, 62.976468206661316] and parameters: {'n_components': 28, 'alpha_H': 0.0003002984436915126, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.1952429877980445}.
# [I 2025-10-10 17:37:09,132] Trial 84 finished with values: [110695.83413047547, 56.15748001475712] and parameters: {'n_components': 30, 'alpha_H': 0.00010300196600986775, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}.
# [I 2025-10-10 17:37:10,573] Trial 85 finished with values: [122665.74531467378, 76.43607892124878] and parameters: {'n_components': 22, 'alpha_H': 0.0007930569433855138, 'alpha_W': 6.955319544158292e-05, 'l1_ratio': 0.8972157579533268}.
# [I 2025-10-10 17:37:11,358] Trial 86 finished with values: [142204.33168063904, 198.02261382403006] and parameters: {'n_components': 12, 'alpha_H': 1.1828996391101272e-05, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.6454722959071678}.
# [I 2025-10-10 17:37:11,673] Trial 87 finished with values: [199748.3032843262, 4049.287652756747] and parameters: {'n_components': 2, 'alpha_H': 0.0027950159165083337, 'alpha_W': 3.398850311078452e-05, 'l1_ratio': 0.9404585843529143}.
# [I 2025-10-10 17:37:12,744] Trial 88 finished with values: [100180.20963423175, 45.15835720840819] and parameters: {'n_components': 39, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}.
# [I 2025-10-10 17:37:13,198] Trial 89 finished with values: [175474.27569279674, 1108.993785756587] and parameters: {'n_components': 4, 'alpha_H': 0.0001446125682015214, 'alpha_W': 0.006459367085984857, 'l1_ratio': 0.9539285770025874}.
# [I 2025-10-10 17:37:14,062] Trial 90 finished with values: [135000.71364067128, 132.91085846695378] and parameters: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5986584841970366}.
# [I 2025-10-10 17:37:14,931] Trial 91 finished with values: [114950.89797541485, 59.26644030591333] and parameters: {'n_components': 28, 'alpha_H': 0.0008113929572637835, 'alpha_W': 8.771380343280557e-05, 'l1_ratio': 0.5085706911647028}.
# [I 2025-10-10 17:37:15,243] Trial 92 finished with values: [199783.93281054986, 4058.2740734205922] and parameters: {'n_components': 2, 'alpha_H': 0.005553837526912238, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:37:15,689] Trial 93 finished with values: [176041.1079155938, 1110.4720828152238] and parameters: {'n_components': 4, 'alpha_H': 0.0027950159165083337, 'alpha_W': 0.001319994226153501, 'l1_ratio': 0.7290071680409873}.
# [I 2025-10-10 17:37:16,658] Trial 94 finished with values: [132512.70520272356, 119.76955876050985] and parameters: {'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}.
# [I 2025-10-10 17:37:18,212] Trial 95 finished with values: [116592.00947085355, 75.59071188606059] and parameters: {'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}.
# [I 2025-10-10 17:37:19,111] Trial 96 finished with values: [141157.79655976698, 162.61340158710163] and parameters: {'n_components': 13, 'alpha_H': 0.00012896625857891436, 'alpha_W': 1.1126788925493283e-05, 'l1_ratio': 0.2912291401980419}.
# [I 2025-10-10 17:37:20,530] Trial 97 finished with values: [102305.19797113445, 42.94702596846749] and parameters: {'n_components': 37, 'alpha_H': 0.0007930569433855138, 'alpha_W': 0.00010401341922663452, 'l1_ratio': 0.3492095746126609}.
# [I 2025-10-10 17:37:21,691] Trial 98 finished with values: [101320.69428860271, 43.5033837539198] and parameters: {'n_components': 39, 'alpha_H': 0.00010300196600986775, 'alpha_W': 0.0067410742656406975, 'l1_ratio': 0.32320293202075523}.
# [I 2025-10-10 17:37:22,788] Trial 99 finished with values: [101637.21532277501, 42.05379046232811] and parameters: {'n_components': 38, 'alpha_H': 0.00019255395572015605, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.4401524937396013}.
# Número de soluções no Pareto front: 44
#
# ➡️ Soluções ótimas (compromissos KL vs Calinski):
# KL=137180.12, Calinski=132.99, Params={'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}
# KL=156223.34, Calinski=328.37, Params={'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}
# KL=116797.91, Calinski=75.98, Params={'n_components': 25, 'alpha_H': 0.001331121608073689, 'alpha_W': 1.1527987128232396e-05, 'l1_ratio': 0.9699098521619943}
# KL=105398.07, Calinski=51.62, Params={'n_components': 34, 'alpha_H': 4.335281794951564e-05, 'alpha_W': 3.511356313970405e-05, 'l1_ratio': 0.18340450985343382}
# KL=141294.44, Calinski=164.00, Params={'n_components': 13, 'alpha_H': 0.00037520558551242813, 'alpha_W': 0.00019762189340280086, 'l1_ratio': 0.2912291401980419}
# KL=116921.13, Calinski=85.71, Params={'n_components': 25, 'alpha_H': 2.621087878265438e-05, 'alpha_W': 7.52374288453485e-05, 'l1_ratio': 0.3663618432936917}
# KL=127367.75, Calinski=108.96, Params={'n_components': 19, 'alpha_H': 0.0022673986523780395, 'alpha_W': 3.972110727381908e-05, 'l1_ratio': 0.5142344384136116}
# KL=116592.01, Calinski=75.59, Params={'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}
# KL=163046.00, Calinski=543.09, Params={'n_components': 6, 'alpha_H': 0.0003058656666978527, 'alpha_W': 1.2681352169084594e-05, 'l1_ratio': 0.9093204020787821}
# KL=168854.83, Calinski=783.23, Params={'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 1.3667272915456215e-05, 'l1_ratio': 0.32533033076326434}
# KL=132512.71, Calinski=119.77, Params={'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}
# KL=176508.11, Calinski=1121.88, Params={'n_components': 4, 'alpha_H': 0.009133995846860976, 'alpha_W': 0.0020736445177905022, 'l1_ratio': 0.1987156815341724}
# KL=106858.85, Calinski=52.01, Params={'n_components': 32, 'alpha_H': 1.6677615430197892e-05, 'alpha_W': 0.0001189589673755355, 'l1_ratio': 0.11586905952512971}
# KL=139939.12, Calinski=139.22, Params={'n_components': 14, 'alpha_H': 9.452571391072311e-05, 'alpha_W': 0.0015446089075047066, 'l1_ratio': 0.6375574713552131}
# KL=103043.15, Calinski=50.50, Params={'n_components': 36, 'alpha_H': 0.00026100256506134736, 'alpha_W': 2.284455685002053e-05, 'l1_ratio': 0.713244787222995}
# KL=149276.56, Calinski=244.97, Params={'n_components': 10, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 7.40038575908737e-05, 'l1_ratio': 0.16122128725400442}
# KL=107756.35, Calinski=67.97, Params={'n_components': 33, 'alpha_H': 0.004878360603452143, 'alpha_W': 8.995191735587162e-05, 'l1_ratio': 0.11005192452767676}
# KL=199292.51, Calinski=4049.63, Params={'n_components': 2, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.22210781047073025}
# KL=100164.29, Calinski=40.87, Params={'n_components': 39, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=141093.51, Calinski=162.20, Params={'n_components': 13, 'alpha_H': 1.2902113024567147e-05, 'alpha_W': 0.0006740513796374046, 'l1_ratio': 0.5026790232288615}
# KL=169265.04, Calinski=792.59, Params={'n_components': 5, 'alpha_H': 0.0032055863990707507, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.18651851039985423}
# KL=180522.76, Calinski=2388.91, Params={'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=122288.27, Calinski=86.59, Params={'n_components': 22, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 1.1919481947918725e-05, 'l1_ratio': 0.16162871409461377}
# KL=168867.11, Calinski=786.08, Params={'n_components': 5, 'alpha_H': 3.872118032174584e-05, 'alpha_W': 0.0011290133559092666, 'l1_ratio': 0.32533033076326434}
# KL=101265.15, Calinski=49.46, Params={'n_components': 38, 'alpha_H': 0.0009783749110062348, 'alpha_W': 1.0355826161899173e-05, 'l1_ratio': 0.8714605901877177}
# KL=141104.24, Calinski=162.21, Params={'n_components': 13, 'alpha_H': 3.0368556852449644e-05, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.7282163486118596}
# KL=180661.52, Calinski=2391.14, Params={'n_components': 3, 'alpha_H': 0.001369423146002436, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=146160.17, Calinski=212.12, Params={'n_components': 11, 'alpha_H': 0.0003405978543532997, 'alpha_W': 0.00017027416886764422, 'l1_ratio': 0.3253996981592677}
# KL=175218.12, Calinski=1117.29, Params={'n_components': 4, 'alpha_H': 5.69307476764461e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=122272.77, Calinski=86.27, Params={'n_components': 22, 'alpha_H': 1.9099601385505377e-05, 'alpha_W': 0.00012327891605450785, 'l1_ratio': 0.9717820827209607}
# KL=106959.42, Calinski=58.33, Params={'n_components': 33, 'alpha_H': 1.7019223026554023e-05, 'alpha_W': 0.004760767751809498, 'l1_ratio': 0.5393422419156507}
# KL=163202.21, Calinski=543.65, Params={'n_components': 6, 'alpha_H': 0.00019112758217777883, 'alpha_W': 0.00284475125551182, 'l1_ratio': 0.3677158030594335}
# KL=156223.34, Calinski=328.37, Params={'n_components': 8, 'alpha_H': 2.9375384576328295e-05, 'alpha_W': 1.493656855461762e-05, 'l1_ratio': 0.8661761457749352}
# KL=180522.76, Calinski=2388.91, Params={'n_components': 3, 'alpha_H': 0.0005924870051994319, 'alpha_W': 0.001078184503512226, 'l1_ratio': 0.016587828927856152}
# KL=146779.72, Calinski=213.79, Params={'n_components': 11, 'alpha_H': 0.00829911273846603, 'alpha_W': 9.169384722192322e-05, 'l1_ratio': 0.3930977246667604}
# KL=114755.74, Calinski=69.21, Params={'n_components': 28, 'alpha_H': 0.0019268985325226215, 'alpha_W': 5.163124910488014e-05, 'l1_ratio': 0.5026370931051921}
# KL=149968.19, Calinski=254.21, Params={'n_components': 10, 'alpha_H': 0.002656813924114493, 'alpha_W': 0.0005379125214937586, 'l1_ratio': 0.16122128725400442}
# KL=142204.33, Calinski=198.02, Params={'n_components': 12, 'alpha_H': 1.1828996391101272e-05, 'alpha_W': 2.6471141828218167e-05, 'l1_ratio': 0.6454722959071678}
# KL=100180.21, Calinski=45.16, Params={'n_components': 39, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.0003102740950912838, 'l1_ratio': 0.30087830981676966}
# KL=135000.71, Calinski=132.91, Params={'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 1.9024283247489577e-05, 'l1_ratio': 0.5986584841970366}
# KL=199783.93, Calinski=4058.27, Params={'n_components': 2, 'alpha_H': 0.005553837526912238, 'alpha_W': 0.000178744632562384, 'l1_ratio': 0.3492095746126609}
# KL=132512.71, Calinski=119.77, Params={'n_components': 17, 'alpha_H': 6.516990611177177e-05, 'alpha_W': 0.003063462210622081, 'l1_ratio': 0.3567533266935893}
# KL=116592.01, Calinski=75.59, Params={'n_components': 25, 'alpha_H': 1.3783237455007187e-05, 'alpha_W': 0.0006647135865318024, 'l1_ratio': 0.17052412368729153}
# KL=141157.80, Calinski=162.61, Params={'n_components': 13, 'alpha_H': 0.00012896625857891436, 'alpha_W': 1.1126788925493283e-05, 'l1_ratio': 0.2912291401980419}
#
# ➡️ Solução mais equilibrada escolhida automaticamente:
# KL=137180.12, Calinski=132.99
# Parâmetros: {'n_components': 16, 'alpha_H': 0.0071144760093434225, 'alpha_W': 0.001570297088405539, 'l1_ratio': 0.5986584841970366}

# %%
nmf_best = NMF(
    n_components=best_params["n_components"],
    init="nndsvda",
    solver="mu",
    beta_loss="kullback-leibler",
    max_iter=MAX_ITER,
    random_state=SEED,
    alpha_H=best_params["alpha_H"],
    alpha_W=best_params["alpha_W"],
    l1_ratio=best_params["l1_ratio"]
)

W_best = nmf_best.fit_transform(X.values)
H_best = nmf_best.components_

# Guardar em DataFrames
df_W = pd.DataFrame(W_best, index=X.index, columns=[f"padrao_{i+1}" for i in range(W_best.shape[1])])
df_H = pd.DataFrame(H_best, columns=X.columns, index=[f"padrao_{i+1}" for i in range(H_best.shape[0])])

print(f"✅ df_W e df_H prontos com Optuna (K={best_params['n_components']})")
# Out:
# ✅ df_W e df_H prontos com Optuna (K=16)

# %%
# ==== Reconstrução final ====
X_hat = W_best @ H_best

# ==== Métricas de erro (NMF final, KL) ====

# Divergência KL
mask = X.values > 0
kl_div = np.sum(
    X.values[mask] * np.log(X.values[mask] / np.maximum(X_hat[mask], 1e-10))
    - X.values[mask] + X_hat[mask]
)

# RMSE e MAE auxiliares
diff = X.values - X_hat
rmse = np.sqrt((diff ** 2).mean())
mae  = np.abs(diff).mean()

print(f"Divergência KL: {kl_div:.6f}")
print(f"RMSE: {rmse:.6f}, MAE: {mae:.6f}")
# Out:
# Divergência KL: 137180.115370
# RMSE: 0.783586, MAE: 0.131546

# %%
df_W.head()
# Out:
#                          padrao_1      padrao_2       padrao_3       padrao_4  \
# timestamp
# 1900-01-01 00:00:00.852  0.000000  0.000000e+00  9.431295e-155   4.226021e-83
# 1900-01-01 00:00:03.401  0.262673  0.000000e+00  5.756467e-252   1.953594e-82
# 1900-01-01 00:00:07.974  0.000000  0.000000e+00   1.308255e+00   0.000000e+00
# 1900-01-01 00:00:08.614  0.000000  1.649873e-47   0.000000e+00   6.107327e-01
# 1900-01-01 00:00:09.458  0.000000  0.000000e+00   1.468883e+00  6.498513e-184
#
#                               padrao_5  padrao_6       padrao_7      padrao_8  \
# timestamp
# 1900-01-01 00:00:00.852   1.195915e-46  0.000000  4.593524e-101  4.508182e-78
# 1900-01-01 00:00:03.401   5.694325e-19  0.599497   2.788895e-51  2.802952e-20
# 1900-01-01 00:00:07.974  1.138317e-271  0.000000   4.752867e-57  3.591706e-76
# 1900-01-01 00:00:08.614   0.000000e+00  0.002216   0.000000e+00  1.455044e-79
# 1900-01-01 00:00:09.458   9.167106e-90  0.000000   1.319310e-48  0.000000e+00
#
#                              padrao_9      padrao_10      padrao_11  \
# timestamp
# 1900-01-01 00:00:00.852  2.806507e-59   1.863434e+00   1.012762e+00
# 1900-01-01 00:00:03.401  3.734614e-61  1.502444e-220   5.382139e-69
# 1900-01-01 00:00:07.974  0.000000e+00   2.669327e-01  4.382321e-115
# 1900-01-01 00:00:08.614  2.497476e-01   0.000000e+00   0.000000e+00
# 1900-01-01 00:00:09.458  0.000000e+00   5.520660e-58   0.000000e+00
#
#                              padrao_12     padrao_13      padrao_14  \
# timestamp
# 1900-01-01 00:00:00.852   1.009208e-81  1.281967e-36  3.629010e-117
# 1900-01-01 00:00:03.401   0.000000e+00  2.958861e-01   2.446862e-78
# 1900-01-01 00:00:07.974   0.000000e+00  1.575743e-82  1.414540e-143
# 1900-01-01 00:00:08.614   4.036409e-01  2.688885e-23   2.562473e-01
# 1900-01-01 00:00:09.458  1.458454e-129  0.000000e+00   0.000000e+00
#
#                             padrao_15  padrao_16
# timestamp
# 1900-01-01 00:00:00.852  1.750227e-20    0.00000
# 1900-01-01 00:00:03.401  1.687845e+00    0.00000
# 1900-01-01 00:00:07.974  0.000000e+00    0.00000
# 1900-01-01 00:00:08.614  0.000000e+00    0.74553
# 1900-01-01 00:00:09.458  3.110900e-14    0.00000

# %%
df_W.to_csv("nmf_W_TS.csv")
